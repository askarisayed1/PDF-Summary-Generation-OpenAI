# %% [markdown]
# # Problem Statement
# __You have been tasked with developing an AI system that can analyze a PDF file and generate a summary. of its contents. Additionally, the system should be integrated with a Chat GPT API to allow users to ask. questions related to the PDF file and received relevant answers__.

# %% [markdown]
# # Objective:
# __The objective of this assignment is to develop an AI system that can__:
# 1. Analyze a PDF file and generate a summary of its contents.
# 2. Integrate with a Chat GPT API to answer user questions related to the PDF file.
# 3. Suggest questions based on the PDF file content.
# 4. Provide successive questions based on user questions.

# %% [markdown]
# # Requirements:
# __The following are the requirements for the AI system__:
# 1. The system should be able to analyze a PDF file and generate a summary of its contents using NLP techniques.
# 2. The system should be integrated with a Chat GPT API to allow users to ask questions related to the PDF file and receive relevant answers.
# 3. The system should be able to suggest questions based on the content of the PDF file.
# 4. The system should provide successive questions based on user questions to allow for a more natural conversation flow.
# 5. The system should be able to handle multiple users concurrently.
# 6. The system should be able to handle errors and exceptions gracefully.

# %% [markdown]
# # Steps to Run-:
# 1. __Install the modules__.
# 2. __Replace the openai key on line 3__.
# 3. __Replace the Pdf file path on line 80__.

# %% [markdown]
# # Module Installation

# %%
! pip install openai
# !pip install pdfplumber
# Out:
# Requirement already satisfied: openai in /opt/anaconda3/lib/python3.8/site-packages (0.27.6)
# Requirement already satisfied: requests>=2.20 in /opt/anaconda3/lib/python3.8/site-packages (from openai) (2.21.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.8/site-packages (from openai) (4.31.1)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.8/site-packages (from openai) (3.8.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->openai) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->openai) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->openai) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->openai) (2021.10.8)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->openai) (20.3.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->openai) (2.0.9)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->openai) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->openai) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->openai) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.8/site-packages (from aiohttp->openai) (1.2.0)

# %%
! pip install pip --upgrade
! pip install pyopenssl --upgrade
# Out:
# Requirement already satisfied: pip in /opt/anaconda3/lib/python3.8/site-packages (23.1.2)
# Requirement already satisfied: pyopenssl in /opt/anaconda3/lib/python3.8/site-packages (20.0.1)
# Collecting pyopenssl
#   Downloading pyOpenSSL-23.1.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: cryptography<41,>=38.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from pyopenssl) (40.0.2)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.8/site-packages (from cryptography<41,>=38.0.0->pyopenssl) (1.14.5)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.12->cryptography<41,>=38.0.0->pyopenssl) (2.20)
# Installing collected packages: pyopenssl
#   Attempting uninstall: pyopenssl
#     Found existing installation: pyOpenSSL 20.0.1
#     Uninstalling pyOpenSSL-20.0.1:
#       Successfully uninstalled pyOpenSSL-20.0.1
# Successfully installed pyopenssl-23.1.1

# %% [markdown]
# # Importing Modules

# %%
import openai
import pdfplumber
openai.api_key = 'Your_OpenAI_key'

# %%
 # Extracts the text content from a PDF file and return in one string
def extract_pdf_text(file_path):
    with pdfplumber.open(file_path) as pdf:
        text = ""
        for page in pdf.pages:
            text += page.extract_text()
        return text
    
# Generates a summary of the input text using OpenAI's text-davinci-003 engine
def generate_summary(text):
    prompt = f"Summarize:\n\n{text[:1000]}"
    response = openai.Completion.create(
        engine='text-davinci-003',
        prompt=prompt,
        max_tokens=300,
        temperature=0.5,
        n=1,
        stop=None
    )
    summary = response.choices[0].text.strip()
    return summary
    
# Generates a specified number of questions based on the given context using OpenAI's text-davinci-003 engine
def generate_questions(context, num_questions):
    response = openai.Completion.create(
        engine='text-davinci-003',
        prompt=context + "\nQ:",
        max_tokens=200,
        temperature=0.5,
        n=num_questions,
        stop=None
    )
    questions = [choice.text.strip() for choice in response.choices]
    return questions

def process_pdf(file_path):
    try:
        # Extract the text from the PDF file
        pdf_text = extract_pdf_text(file_path)

        # Generate the summary of the extracted text
        summary = generate_summary(pdf_text)

        # Generate initial questions
        num_initial_questions = 5
        initial_questions = generate_questions(pdf_text, num_initial_questions)

        # Prepare output
        output = {
            'file_path': file_path,
            'summary': summary,
            'initial_questions': initial_questions
        }

        # Print the summary and initial questions
        print(f"\nSummary for file '{file_path}':\n{summary}")

        print(f"\nInitial Questions for file '{file_path}':")
        for i, question in enumerate(initial_questions):
            print(f"Question {i+1}: {question}")

        # Ask the user for additional questions
        user_questions = []
        while True:
            user_input = input("\nDo you have any questions? (Y/N): ")
            if user_input.lower() == 'n':
                break
            elif user_input.lower() == 'y':
                question = input("Your Question: ")
                user_questions.append(question)
            else:
                print("Invalid input. Please enter 'Y' for yes or 'N' for no.")

        output['user_questions'] = user_questions

        return output

    except Exception as e:
        error_message = f"An error occurred: {str(e)}"
        return {'file_path': file_path, 'error': error_message}

# Specify the paths to the PDF files
pdf_paths = ['FrenchInput.pdf', 'Analysis Report_ Comparison of Different Models for Dispense Amount Prediction.pdf', 'hindiinput.pdf']

# Process the PDF files
results = []
for pdf_path in pdf_paths:
    result = process_pdf(pdf_path)
    results.append(result)

# Print the final results
for result in results:
    file_path = result['file_path']
    if 'error' in result:
        print(f"Error processing file '{file_path}': {result['error']}")
    else:
        print(f"\nFile: '{file_path}'")
        print("\nUser Questions:")
        for i, question in enumerate(result['user_questions']):
            print(f"Question {i+1}: {question}")
# Out:
# Summary for file 'FrenchInput.pdf':
# ées pour entraîner le
# modèle, tandis que les données de test sont utilisées pour évaluer la précision du modèle.
# 4. Entraînement du modèle : Une fois que les données sont prêtes, le modèle est entraîné.
# 5. Évaluation du modèle : Enfin, le modèle est évalué en utilisant des métriques spécifiques pour
# mesurer sa précision et sa performance.
#
# La modélisation prédictive est une technique de science des données qui consiste à identifier des modèles et des relations dans des données afin de faire des prédictions. Le processus de modélisation prédictive comprend la compréhension des données, la sélection des caractéristiques pertinentes, la division des données en ensembles d'entraînement et de test, l'entraînement du modèle et l'évaluation du modèle.
#
# Initial Questions for file 'FrenchInput.pdf':
# Question 1: Quels sont les avantages de la modélisation prédictive ?
#
# R: Les avantages de la modélisation prédictive comprennent :
# 1. Prédire le comportement et les tendances futures : La modélisation prédictive permet de prédire le comportement et les tendances futures à partir des données passées. Cela peut aider les entreprises à prendre des décisions éclairées et à planifier leurs activités.
# 2. Optimiser les performances : Les modèles prédictifs peuvent être utilisés pour optimiser les performances des systèmes en identifiant les variables et les relations les plus importantes.
# 3. Économiser du temps et des ressources : La modélisation pr
# Question 2: Quels sont les avantages de la modélisation prédictive ?
#
# Les avantages de la modélisation prédictive sont nombreux. Il peut aider les entreprises à prendre des décisions plus éclairées et à optimiser leurs performances. Il peut également aider à identifier et à comprendre les modèles et les relations cachés dans les données. Il peut aussi aider à prédire des résultats futurs et à améliorer l'efficacité des processus.
# Question 3: Quels sont les avantages de la modélisation prédictive ?
#
# Les avantages de la modélisation prédictive sont nombreux. Il permet aux entreprises de mieux comprendre leurs données et de prendre des décisions plus éclairées. Il peut également aider à réduire le temps et les coûts associés à la prise de décision. Il permet également de prendre des décisions plus précises en prédisant les résultats futurs. Il peut également être utilisé pour optimiser les performances et trouver des solutions plus efficaces à des problèmes complexes.
# Question 4: Quels sont les avantages de la modélisation prédictive?
#
# Les avantages de la modélisation prédictive sont nombreux et comprennent :
#
# 1. Permet de prendre des décisions plus éclairées : La modélisation prédictive permet aux
# organisations de prendre des décisions plus éclairées en leur fournissant des prédictions
# détaillées et précises sur leurs activités et leurs opérations.
#
# 2. Améliore l'efficacité : La modélisation prédictive peut aider à améliorer l'efficacité des
# opérations en identifiant des modèles et des relations dans les données. Cela permet aux
# organ
# Question 5: Qu'est-ce que la modélisation prédictive?
#
# R: La modélisation prédictive est une technique importante en science des données qui est utilisée pour faire des prédictions basées sur des données. Elle identifie les modèles et les relations spécifiques dans les données, puis tente de faire des prédictions en utilisant ces modèles. Elle est utilisée dans de nombreux domaines tels que la finance, la santé, le marketing, etc., pour prédire des résultats futurs, prendre des décisions éclairées et optimiser les performances.
#
# Do you have any questions? (Y/N): No
# Invalid input. Please enter 'Y' for yes or 'N' for no.
#
# Do you have any questions? (Y/N): N
#
# Summary for file 'Analysis Report_ Comparison of Different Models for Dispense Amount Prediction.pdf':
# for testing.
#
# This analysis report compares the performance of different models for predicting the dispense amount in an ATM system. The objective was to identify the most accurate and reliable model for forecasting dispense amounts. The dataset used for the analysis contained historical dispense amounts along with various features such as date, ATM ID, and transaction details. The dataset was split into training and test sets. The ARIMA model was used to capture the temporal patterns and seasonality in the dispense amounts. The model achieved a training score of 0.81 and a test score of 0.79, indicating good performance in capturing the underlying patterns in the data. Hyperparameter tuning was performed, resulting in a slight improvement in the scores to 0.80 for training and 0.81 for testing.
#
# Initial Questions for file 'Analysis Report_ Comparison of Different Models for Dispense Amount Prediction.pdf':
# Question 1: WhataretheadvantagesanddisadvantagesofusingARIMA,SARIMAX,andXGBoostmodelsfor
# dispenseamountprediction?
#
# Advantages of ARIMA:
# • ARIMA models are easy to use and interpret.
# • ARIMA models are effective in capturing temporal patterns and seasonality in the data.
# • ARIMA models are relatively inexpensive to train and can be optimized with hyperparameter tuning.
#
# Disadvantages of ARIMA:
# • ARIMA models are limited in their ability to capture complex relationships and non-linear patterns in the data.
#
# Advantages of SARIMAX:
# • SARIMAX models are an extension of ARIMA models, incorporating exogenous variables in addition to the time series data.
# • SARIMAX models are effective in capturing complex relationships and non-linear patterns in the data.
#
# Disadvantages of SARIMAX:
# Question 2: WhataretheadvantagesofusingtheARIMAModelfordispenseamountprediction?
#
# A:TheARIMA modelhasseveraladvantagesfor dispenseamountprediction.First,itiseffectiveatcapturingthetemporalpatternsandseasonalityinthedispenseamounts,whichcanhelpforecastfuture dispenseamountsmoreaccurately.Second,itiseasytotuneandoptimizeforbetterperformance.Third,itoffersflexibilityinincorporatingexogenousvariables,allowingforamorecomplexrelationshipbetweenthevariables.Finally,itisefficientinprocessinglargeamountsofdata,whichmakesitidealforreal-timeapplications.
# Question 3: WhataretheadvantagesofusingtheARIMAmodelfordispenseamountprediction?
#
# A:TheARIMA modelhasseveraladvantagesfordispenseamountprediction.Firstly,itcaneffectivelycapturethetemporalpatterns andseasonalityin thedispenseamounts.Secondly,itcanbeeasilytunedusinghyperparameterstoimproveitsperformance.Finally,itcanbeusedforbothshort-termandlong-termforecasting.
# Question 4: What are the advantages of using the ARIMA model for dispense amount prediction?
#
# A:The ARIMA model has several advantages for dispense amount prediction. Firstly, it is able to capture the temporal patterns and seasonality in the data, which is important for accurately forecasting future dispense amounts. Secondly, it is relatively simple to implement and can be easily tuned with hyperparameters to improve accuracy. Additionally, the ARIMA model is computationally efficient and can be used for large datasets. Finally, it is a reliable model and has been used successfully in many applications.
# Question 5: WhataretheadvantagesofusingARIMAmodelforpredictingdispenseamounts?
# A:TheadvantagesofusingARIMAmodelforpredictingdispenseamountsinclude:
# •Itisabletoeffectivelycapturetemporalpatternsandseasonalityinthedispenseamounts.
# •Itcanbeoptimizedthroughhyperparametertuning.
# •Itisrelativelysimpletomodelandimplement.
# •Itprovidesaccurateandconsistentpredictions.
#
# Do you have any questions? (Y/N): N
#
# Summary for file 'hindiinput.pdf':
# Predictive modeling is a data science technique that is used to make predictions based on data. It uses data to identify patterns and make predictions about future outcomes. Predictive modeling can be used to identify trends and make predictions about data. The process of predictive modeling involves several steps: understanding the data, selecting features, training the model, and evaluating the model. Finally, the model is used to generate insights and make predictions.
#
# Initial Questions for file 'hindiinput.pdf':
# Question 1: What is Predictive Modeling?
#
# A: Predictive modeling is a type of data analytics technique that uses data and statistical algorithms to predict outcomes and make decisions. It is used to identify patterns and trends in data and to make predictions about future events. Predictive models are used to identify customer behavior, market trends, and other insights that can be used to make decisions and take actions.
# Question 2: What is Predictive Modeling?
#
# A:Predictive modeling is a type of data mining technique that uses data and analytics to predict future outcomes. It is used to identify patterns and trends in data in order to make predictions about future events. Predictive models can be used to identify potential customers, forecast market trends, and optimize business processes.
# Question 3: What is Predictive Modeling?
#
# A: Predictive modeling is a data mining technique used to make predictions and identify patterns by analyzing data and building models based on that data. It is used to identify trends and patterns in data in order to make predictions about future events or outcomes. Predictive modeling can be used to identify potential customers, optimize marketing campaigns, predict customer churn, and more.
# Question 4: What is Predictive Modeling?
#
# A: Predictive modeling is a data analytics technique that uses data and statistical algorithms to predict outcomes and behaviors. It is used to identify patterns and trends in data in order to make predictions and to help make decisions. Predictive modeling consists of several steps: understanding the data, selecting features, building the model, and testing and evaluating the model.
# Question 5: What is Predictive Modeling?
#
# Answer: Predictive Modeling is a data science technique that uses data analysis and machine learning algorithms to identify patterns and make predictions about future outcomes. It is used to identify trends and relationships in data and to make predictions about future events based on those patterns. Predictive Modeling involves the following steps: understanding the data, selecting features, training the model, and evaluating performance.
#
# Do you have any questions? (Y/N): N
#
# File: 'FrenchInput.pdf'
#
# User Questions:
#
# File: 'Analysis Report_ Comparison of Different Models for Dispense Amount Prediction.pdf'
#
# User Questions:
#
# File: 'hindiinput.pdf'
#
# User Questions:
